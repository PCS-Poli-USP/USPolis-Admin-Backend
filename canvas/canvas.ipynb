# %%
import boto3

client = boto3.client('cognito-idp', region_name='us-east-2')
# Out:
# ---------------------------------------------------------------------------
# NotAuthorizedException                    Traceback (most recent call last)
# /home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import boto3
#       <a href='vscode-notebook-cell:/home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> client = boto3.client('cognito-idp', region_name='us-east-2')
# ----> <a href='vscode-notebook-cell:/home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> client.get_user(AccessToken="RPojUXKR31NmjWfj9nZD9Ndl9UHhDc7sssinj3byciYLW0qUVFh-jLiGmyVvkIt-U16fhncHHElexISj1CScoCwVtTzIP1pI8ByAZYG0V3lOzXNG4tbqH0A4r8OwUi1fyW29vEOt9pWKpvpAE-JnKMoiHqApf4FirNx9bYX4sGFVImjANDVnuFSCcgf2C4ifKpYuhLe_ogR3LOPqmGWJrNzU0PyYqctMEC4BLgbgrUd13hiGbnTQKvsqquFWsdsq6bSrj6Os3ZuCPx_gt9RWSxaBlfvelApG2d_LtJaeBGD_6MngpOWq4OY5BIC9eyBGmnWJOsH1kc6ti5pYEMBmWg")
#
# File ~/progs/USPolis/USPolis-Admin-Backend/.venv/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File ~/progs/USPolis/USPolis-Admin-Backend/.venv/lib/python3.10/site-packages/botocore/client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# NotAuthorizedException: An error occurred (NotAuthorizedException) when calling the GetUser operation: Invalid Access Token

# %%
client.get_user(AccessToken="eyJraWQiOiJcL2dpRXV5ZDd3d1wvWVl0cWFZS2hCeldVQWI1eUR4clgxV0RVeTJRZUl3bjQ9IiwiYWxnIjoiUlMyNTYifQ.....N0d2afexPlBQRoNpdrdq14ifXqnCvl_Bk9apqhbhargsVn8YIBiODnkZM6q5jMYXhqE3fJA6eDF8ilvQVLdD1lXsE1SxmgpVjCkiDxDtyPw2QO7kuChuausqdO4ZdDRJBqQdJPuUN1kZwydBOnIJQZIm-3w0KsdK6xmkV4eSMj3RXECeyk0DWaVs7Q8AnMswXvyCDTSOJH6awPAI5VmGjvvabU8BcINuRfKqRwFjd2e8tv9olCSQL6GwsQNySkjxemcr3VPdNUR2qM5uux3-SJXrIvOYxcczhGFyWuSpqNr9QZ6oy-c7SrfwEOd9jcMOJoha41xYDpRfughT_7KR6w")
# Out:
# {'Username': 'hfduran',
#  'UserAttributes': [{'Name': 'sub',
#    'Value': 'c2bd550f-483b-4133-a2d0-c6a2f519d634'},
#   {'Name': 'email_verified', 'Value': 'true'},
#   {'Name': 'email', 'Value': 'henriqueduran15@gmail.com'}],
#  'ResponseMetadata': {'RequestId': '03ec69ef-35b7-4559-9500-e331b619b251',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Tue, 17 Oct 2023 02:49:45 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '197',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '03ec69ef-35b7-4559-9500-e331b619b251'},
#   'RetryAttempts': 0}}

# %%
client.list_users(UserPoolId="us-east-2_XJgPdnYEw")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/home/hfduran/progs/USPolis/USPolis-Admin-Backend/canvas/canvas.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> client.list_users(UserPoolId="us-east-2_XJgPdnYEw")
#
# File ~/progs/USPolis/USPolis-Admin-Backend/.venv/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File ~/progs/USPolis/USPolis-Admin-Backend/.venv/lib/python3.10/site-packages/botocore/client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ClientError: An error occurred (AccessDeniedException) when calling the ListUsers operation: User: arn:aws:iam::392822589475:user/uspolis-admin is not authorized to perform: cognito-idp:ListUsers on resource: arn:aws:cognito-idp:us-east-2:392822589475:userpool/us-east-2_XJgPdnYEw because no identity-based policy allows the cognito-idp:ListUsers action
